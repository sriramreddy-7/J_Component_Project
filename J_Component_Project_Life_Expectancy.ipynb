# %% [markdown]
# <a href="https://colab.research.google.com/github/sriramreddy-7/J_Component_Project/blob/main/J_Component_Project_Life_Expectancy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler

# %%
data=pd.read_csv("LIFE_EXPECT.csv.csv")
data.head()
data.isnull().sum()
x=data.drop(['age'],axis=1)
y=data['age']

print(x)
print(y)

sc=StandardScaler()
data=sc.fit(x)
dd=sc.transform(x)
print(data)
print(dd)
print(x)
print(dd)

print(x)
# Out:
#      sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0      1   3       145   233    1        0      150      0      2.3      0
# 1      1   2       130   250    0        1      187      0      3.5      0
# 2      0   1       130   204    0        0      172      0      1.4      2
# 3      1   1       120   236    0        1      178      0      0.8      2
# 4      0   0       120   354    0        1      163      1      0.6      2
# ..   ...  ..       ...   ...  ...      ...      ...    ...      ...    ...
# 298    0   0       140   241    0        1      123      1      0.2      1
# 299    1   3       110   264    0        1      132      0      1.2      1
# 300    1   0       144   193    1        1      141      0      3.4      1
# 301    1   0       130   131    0        1      115      1      1.2      1
# 302    0   1       130   236    0        0      174      0      0.0      1
#
#      ca  thal  target
# 0     0     1       1
# 1     0     2       1
# 2     0     2       1
# 3     0     2       1
# 4     0     2       1
# ..   ..   ...     ...
# 298   0     3       0
# 299   0     3       0
# 300   2     3       0
# 301   1     3       0
# 302   1     2       0
#
# [303 rows x 13 columns]
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64
# StandardScaler()
# [[ 0.68100522  1.97312292  0.76395577 ... -0.71442887 -2.14887271
#    0.91452919]
#  [ 0.68100522  1.00257707 -0.09273778 ... -0.71442887 -0.51292188
#    0.91452919]
#  [-1.46841752  0.03203122 -0.09273778 ... -0.71442887 -0.51292188
#    0.91452919]
#  ...
#  [ 0.68100522 -0.93851463  0.70684287 ...  1.24459328  1.12302895
#   -1.09345881]
#  [ 0.68100522 -0.93851463 -0.09273778 ...  0.26508221  1.12302895
#   -1.09345881]
#  [-1.46841752  0.03203122 -0.09273778 ...  0.26508221 -0.51292188
#   -1.09345881]]
#      sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0      1   3       145   233    1        0      150      0      2.3      0
# 1      1   2       130   250    0        1      187      0      3.5      0
# 2      0   1       130   204    0        0      172      0      1.4      2
# 3      1   1       120   236    0        1      178      0      0.8      2
# 4      0   0       120   354    0        1      163      1      0.6      2
# ..   ...  ..       ...   ...  ...      ...      ...    ...      ...    ...
# 298    0   0       140   241    0        1      123      1      0.2      1
# 299    1   3       110   264    0        1      132      0      1.2      1
# 300    1   0       144   193    1        1      141      0      3.4      1
# 301    1   0       130   131    0        1      115      1      1.2      1
# 302    0   1       130   236    0        0      174      0      0.0      1
#
#      ca  thal  target
# 0     0     1       1
# 1     0     2       1
# 2     0     2       1
# 3     0     2       1
# 4     0     2       1
# ..   ..   ...     ...
# 298   0     3       0
# 299   0     3       0
# 300   2     3       0
# 301   1     3       0
# 302   1     2       0
#
# [303 rows x 13 columns]
# [[ 0.68100522  1.97312292  0.76395577 ... -0.71442887 -2.14887271
#    0.91452919]
#  [ 0.68100522  1.00257707 -0.09273778 ... -0.71442887 -0.51292188
#    0.91452919]
#  [-1.46841752  0.03203122 -0.09273778 ... -0.71442887 -0.51292188
#    0.91452919]
#  ...
#  [ 0.68100522 -0.93851463  0.70684287 ...  1.24459328  1.12302895
#   -1.09345881]
#  [ 0.68100522 -0.93851463 -0.09273778 ...  0.26508221  1.12302895
#   -1.09345881]
#  [-1.46841752  0.03203122 -0.09273778 ...  0.26508221 -0.51292188
#   -1.09345881]]
#      sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0      1   3       145   233    1        0      150      0      2.3      0
# 1      1   2       130   250    0        1      187      0      3.5      0
# 2      0   1       130   204    0        0      172      0      1.4      2
# 3      1   1       120   236    0        1      178      0      0.8      2
# 4      0   0       120   354    0        1      163      1      0.6      2
# ..   ...  ..       ...   ...  ...      ...      ...    ...      ...    ...
# 298    0   0       140   241    0        1      123      1      0.2      1
# 299    1   3       110   264    0        1      132      0      1.2      1
# 300    1   0       144   193    1        1      141      0      3.4      1
# 301    1   0       130   131    0        1      115      1      1.2      1
# 302    0   1       130   236    0        0      174      0      0.0      1
#
#      ca  thal  target
# 0     0     1       1
# 1     0     2       1
# 2     0     2       1
# 3     0     2       1
# 4     0     2       1
# ..   ..   ...     ...
# 298   0     3       0
# 299   0     3       0
# 300   2     3       0
# 301   1     3       0
# 302   1     2       0
#
# [303 rows x 13 columns]

# %%
x=dd['thal'] 
y=dd['age'] 
plt.xlabel("Thalassemia")
plt.ylabel("Age")
plt.title("Thalassemia vs Age") 
plt.scatter(x,y)

# %%
x=dd['cp'] 
y=dd['age'] 
plt.xlabel("Constrictive pericarditis")
plt.ylabel("Age")
plt.title("Age vs Constrictive pericarditis") 
plt.scatter(x,y)

# %%
x=dd['trestbps'] 
y=dd['age'] 
plt.xlabel("Blood Pressure")
plt.ylabel("Age")
plt.title("Blood pressure vs Age")
plt.scatter(x,y)

# %%
dd=df.fillna(0)
x=dd['chol'] 
y=dd['age'] 
plt.xlabel("cholesterol")
plt.ylabel("Age")
plt.title("Cholesterol vs Age")
plt.scatter(x,y)

# %%
x=dd['fbs'] 
y=dd['age'] 
plt.xlabel("Blood Sugar")
plt.ylabel("Age")
plt.title("Age vs Blood Sugar") 
plt.scatter(x,y)

# %%
dd=df.fillna(0)
x=dd['restecg'] 
y=dd['age'] 
plt.xlabel("Ectrocardiographic")
plt.ylabel("Age")
plt.title("Age vs Ectrocardiographic") 
plt.scatter(x,y)

# %%
x=dd['thalach'] 
y=dd['age'] 
plt.xlabel("Maximum heart rate achieved")
plt.ylabel("Age")
plt.title("Age vs Maximum heart rate achieved") 
plt.scatter(x,y)

# %%
x=dd['exang'] 
y=dd['age'] 
plt.xlabel("Induced Angina")
plt.ylabel("Age")
plt.title("Age vs Induced Angina") 
plt.scatter(x,y)

# %%
x=dd['oldpeak'] 
y=dd['age'] 
plt.xlabel("Exercise relative")
plt.ylabel("Age")
plt.title("Age vs Exercise relative") 
plt.scatter(x,y)

# %%
x=dd['slope'] 
y=dd['age'] 
plt.xlabel("ST/heart rate slope")
plt.ylabel("Age")
plt.title("Age vs ST/heart rate slope") 
plt.scatter(x,y)

# %%
x=dd['ca'] 
y=dd['age'] 
plt.xlabel("coronary artery calcium")
plt.ylabel("Age")
plt.title("Age vs coronary artery calcium") 
plt.scatter(x,y)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=True)
from sklearn import linear_model
lin_reg_model=LinearRegression()

reg=lin_reg_model.fit(x_train,y_train)

w=reg.score(x_test,y_test)

reg.score(x_train,y_train)

train_prediction=lin_reg_model.predict(x_train)

error_score=metrics.r2_score(y_train,train_prediction)

print("Linear Regression:", error_score)


plt.scatter(y_train,train_prediction)
# Out:
# Linear Regression: 0.30503242634446204

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=True)
from sklearn import linear_model
lasso_reg=linear_model.Lasso(alpha=50,max_iter=100,tol=0.1)
lasso_reg.fit(x_train,y_train)

j=lasso_reg.score(x_test,y_test)
trainl_prediction=lasso_reg.predict(x_train)
error2_score=metrics.r2_score(y_train,trainl_prediction)
print("Lasso Regression:", error2_score)


plt.scatter(y_train,trainl_prediction)
jj=lasso_reg.score(x_train,y_train)
# Out:
# Lasso Regression: 0.12595077322184733

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=True)
from sklearn.linear_model import Ridge
Ridge_reg=linear_model.Ridge(alpha=50,max_iter=100,tol=0.1)
Ridge_reg.fit(x_train,y_train)
trainr_prediction=Ridge_reg.predict(x_train)
error_scorer=metrics.r2_score(y_train,trainr_prediction)
print("Ridge Regression:", error_scorer)
ff=Ridge_reg.score(x_train,y_train)

ll=Ridge_reg.score(x_test,y_test)
import matplotlib.pyplot as plt
plt.scatter(y_train,trainr_prediction)
# Out:
# Ridge Regression: 0.29947544587388797
